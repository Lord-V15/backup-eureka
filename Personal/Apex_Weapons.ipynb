# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
w_df=pd.read_csv('weapons.csv')

# %%
w_df.head()
# Out:
#        name  damage  headshot_damage  legshot_damage  rate_of_fire  \
# 0  Flatline      16             32.0            12.0           600
# 1    Hemlok      18             36.0            13.5           490
# 2     R-301      14             28.0            10.5           720
# 3     Havoc      18             36.0            13.5           672
# 4      R-99      12             18.0             9.6          1080
#
#    ammo_capacity  tactical_reload  empty_reload ammo_type  projectile_speed  \
# 0             20              2.4          3.10     heavy               650
# 1             18              2.4          2.85     heavy               688
# 2             18              2.4          3.20     light               725
# 3             32              2.4          3.20    energy               763
# 4             18              1.8          2.45     light               525
#
#    ...  spray_pattern/starter/7/x  spray_pattern/starter/7/y  \
# ...

# %%
ef=w_df[['name','damage','rate_of_fire','ammo_type','ammo_type']]
ef.head()
# Out:
#        name  damage  rate_of_fire ammo_type ammo_type
# 0  Flatline      16           600     heavy     heavy
# 1    Hemlok      18           490     heavy     heavy
# 2     R-301      14           720     light     light
# 3     Havoc      18           672    energy    energy
# 4      R-99      12          1080     light     light

# %%
plt.bar(ef['name'].iloc[2:15],ef['damage'].iloc[2:15],width=0.3)
# Out:
# <BarContainer object of 13 artists>

# %%
#matplotlib plot size prams
